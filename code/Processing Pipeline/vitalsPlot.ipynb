# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['svg.fonttype']='none'
plt.rcParams['pdf.fonttype']='truetype'

# subject indexing
# 1 = 15
# 2 = 13
# 3 = 14

# %%
HRdf = pd.read_csv('HRdata.csv')
HRdf = HRdf[:-1]
# for iSub in range(1,4): 
#     f,ax = plt.subplots(1,2,figsize=[12,5])
#     sns.stripplot(x='trial',y='HR',hue='label',data=HRdf[HRdf['Subject']==iSub],jitter=0.05,dodge=True,ax=ax[0])
#     sns.boxplot(x='trial',y='HR',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[0])

#     sns.barplot(x='trial',y='HR',hue='label',data=HRdf[HRdf['Subject']==iSub])

sns.catplot(x='trial',y='HR',hue='label',data=HRdf,col="Subject",kind='bar')
plt.savefig('HR.pdf')

# %%
HRdf = pd.read_csv('Respdata.csv')
# for iSub in range(1,4): 
#     f,ax = plt.subplots(1,2,figsize=[12,5])
#     sns.stripplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],jitter=0.05,dodge=True,ax=ax[0])
#     sns.boxplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[0])

#     sns.barplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[1])

sns.catplot(x='trial',y='Resp',hue='label',data=HRdf,col="Subject",kind='bar')
plt.savefig('Resp.pdf')

# %%
HRdf = pd.read_csv('TemperatureData.csv')
# for iSub in range(1,4): 
#     f,ax = plt.subplots(1,2,figsize=[12,5])
#     sns.stripplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],jitter=0.05,dodge=True,ax=ax[0])
#     sns.boxplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[0])

#     sns.barplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[1])
HRdf['Temp'] = (HRdf['Temp']-32)/1.8
sns.catplot(x='trial',y='Temp',hue='label',data=HRdf,col="Subject",kind='bar')
plt.savefig('Temp.pdf')

# %%
HRdf = pd.read_csv('BPdata.csv')
# for iSub in range(1,4): 
#     f,ax = plt.subplots(1,2,figsize=[12,5])
#     sns.stripplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],jitter=0.05,dodge=True,ax=ax[0])
#     sns.boxplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[0])

#     sns.barplot(x='trial',y='Resp',hue='label',data=HRdf[HRdf['Subject']==iSub],ax=ax[1])

sns.catplot(x='trial',y='BP',hue='label',data=HRdf,col="Subject",kind='bar')
plt.savefig('BP.pdf')
